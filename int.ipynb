# %%
import pandas as pd

df = pd.read_csv("sdu_form.csv")

int_columns_ddl = [
  "user_id",
  "dx_number_ogorodov",
  "labour_population",
  "labour_constant_population",
  "labour_labour",
  "labour_goverment_workers",
  "labour_private_labour",
  "labour_private_ogorod",
  "labour_total_econ_inactive_population",
  "labour_unemployed",
  "labour_household_size",
  "labour_average_income_family",
  "house_total_dvor",
  "house_zaselen_dvor",
  "dh_count",
  "kx_amount",
  "animal_dvor",
  "animal_skot_bird",
  "animal_krs_milk",
  "animal_krs_meat",
  "animal_sheep",
  "animal_kozel",
  "animal_horse",
  "animal_camel",
  "animal_pig",
  "animal_chicken",
  "animal_gusi",
  "animal_duck",
  "animal_induk",
  "animal_egg_total",
  "animal_egg_chicken",
  "animal_egg_gusi",
  "animal_egg_perepel",
  "animal_transformator",
  "animal_transformator_isused",
  "infrastructure_polivochnaya_sistema_",
  "infrastructure_polivochnaya_sistema_isused",
  "infrastructure_mtm",
  "infrastructure_mtm_isused",
  "infrastructure_slad",
  "infrastructure_slad_isused",
  "infrastructure_garage",
  "infrastructure_garage_isused",
  "infrastructure_cycsterny",
  "infrastructure_cycsterny_isused",
  "infrastructure_transformator",
  "infrastructure_transformator_isused",
  "noncx_sto",
  "noncx_sto_needs",
  "noncx_kindergarden",
  "noncx_kindergarden_needs",
  "noncx_souvenier",
  "noncx_souvenier_needs",
  "noncx_pc_service",
  "noncx_pc_service_needs",
  "noncx_store",
  "noncx_store_needs",
  "noncx_remont_bytovoi_tech",
  "noncx_remont_bytovoi_tech_needs",
  "noncx_metal",
  "noncx_metal_needs",
  "noncx_accounting",
  "noncx_accounting_needs",
  "noncx_photo",
  "noncx_photo_needs",
  "noncx_turism",
  "noncx_turism_needs",
  "noncx_rent",
  "noncx_rent_needs",
  "noncx_cargo",
  "noncx_cargo_needs",
  "noncx_massage",
  "noncx_massage_needs",
  "noncx_foodcourt",
  "noncx_foodcourt_needs",
  "noncx_cleaning",
  "noncx_cleaning_needs",
  "noncx_beuty",
  "noncx_beuty_needs",
  "noncx_carwash",
  "noncx_carwash_needs",
  "noncx_atelie",
  "noncx_atelie_needs",
  "noncx_others",
  "noncx_others_needs",
  "noncx_stroika",
  "noncx_stroika_needs",
  "noncx_mebel",
  "noncx_mebel_needs",
  "noncx_stroi_material",
  "noncx_stroi_material_needs",
  "noncx_svarka",
  "noncx_svarka_needs",
  "noncx_woodworking",
  "noncx_woodworking_needs",
  "noncx_others_uslugi",
  "noncx_others_needs_uslugi",
  "credit_amount",
  "credit_total",
  "credit_average_total"
]


float_columns_df = df.select_dtypes(include='float').columns

# Convert float columns to integers if they are also present in the int columns list
columns_to_convert = [col for col in float_columns_df if col in int_columns_ddl]
df[columns_to_convert] = df[columns_to_convert].astype(int)

# Save the modified DataFrame to a new CSV file or overwrite the existing one
df.to_csv("sdu_form3.csv", index=False)
